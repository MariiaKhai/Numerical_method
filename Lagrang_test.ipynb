# %% [markdown]
# # Laboratory work №6
# ## INTERPOLATION BY POLYNOMIALS LAGRANGE APPROXIMATION

# %% [markdown]
# Construct the Lagrange interpolation polynomial for the function

# %% [markdown]
# ### Tasks
#
# |Variant|
# |---|---|---|---|---|
# |№1|x| 1.4  |1,8   |  2,3 |  2,9 |
# | |f(x)| 0,3365  |  0.5878 |  0.8329 | 1.0647   |
# |№2|x| 2.0  |2.5   |  2.8 |  3.3 |
# | |f(x)| 0,6931  |  0.9163 |  1.0296 | 1,1939  |
# |№3|x| 4.0  |4.5   |  4.9 |  5.4 |
# | |f(x)| 1,3863  |  1,5041 |  1.5892 | 1.6864  |
# |№4|x| 1.2  |1.6   |  2.1 |  2.6 |
# | |f(x)| 0,1823 |  0,4700|  0.7419 | 1.6864  |
# |№5|x| 2.2  |2.7   |  3.1 |  3.6 |
# | |f(x)| 0,7885|  0,9933| 1.1314 | 1,2809  |
# |№6|x| 3.2  |3.6   |  4.1 |  4.6 |
# | |f(x)| 1,1632|  1.2809| 1,4110 | 1.5261  |
# |№7|x| 3.4  |3.9   |  4.3 |  4.9 |
# | |f(x)| 1,2238|  1,3610| 1,4586 | 1.5861  |
# |№8|x| 1.6  |2.1   |  2.7 |  8.2 |
# | |f(x)| 0,4700|  0,7419| 0,9933 | 1,1632  |
# |№9|x| 2.8  |3.1   |  3.7 |  4.2 |
# | |f(x)| 1,0296|  1.1314| 1,3083 | 1,4351  |
# |№10|x| 3.1 |3.6   |  4.0 |  4.6 |
# | |f(x)| 1,1314|  1,2809| 1,З863 | 1,5261  |
# |№11|x| 1.9 |2.5   |  2.9 |  3.4 |
# | |f(x)| 0.6419|  0.9163| 1.0647 | 1.2238  |
# |№12|x| 1.7 |2.2   |  2.8 |  3.2 |
# | |f(x)| 0.5306|  0.7885| 1,0296 | 1.1632  |
# |№13|x| 3.6 |4.2   |  4.5 |  5.2 |
# | |f(x)| 1.2809|  1,4351| 1,5041 | 1,6094  |
# |№14|x| 2.5 |2.9   |  3.6 |  4.1 |
# | |f(x)| 0.9163|  1.0647| 1.2809 | 1.4110  |
# |№15|x| 3.3 |3.9   |  4.4 |  5.0 |
# | |f(x)| 1.1939|  1.3610| 1,4816 | 1.6094  |
# |№16|x| 1.1 |1.7   |  2.4 |  2.8 |
# | |f(x)| 0.0953|  0.5306| 0.6755 | 1.0296  |
# |№17|x| 2.1 |2.5   |  3.0 |  3.5 |
# | |f(x)| 0.7419|  0.9163| 1.0986 | 1.2528  |
# |№18|x| 3.2 |3.7   |  4.3 |  4.9 |
# | |f(x)| 1.1632|  1,3083| 1,4586 | 1,5892  |
# |№19|x| 2.7 |3.3   |  3.8 |  4.6 |
# | |f(x)| 0.9933|  1,1939| 1,З350 | 1,5261  |
# |№20|x| 1.0 |1.5   |  2.1 |  2.7 |
# | |f(x)| 0.0000|  0.4055| 0.7419 | 0.9933  |
# |№21|x| 1.4 |1.9   |  2.6 |  3.0 |
# | |f(x)| 0.3365|  0.6419| 0.9555 | 1.0986  |
# |№22|x| 3.1 |3.7   |  4.2 |  4.8 |
# | |f(x)| 1.1314|  1,3083| 1,4351 | 1,5686  |
# |№23|x| 2.6 |3.2   |  4.0 |  4.5 |
# | |f(x)| 0.9555|  1,1632| 1,З863 | 1,5041  |
# |№24|x| 1.6 |2.2   |  2.7 |  8.4 |
# | |f(x)| 0.4700|  0.7885| 0.9933 | 1.2238  |
# |№25|x| 2.1 |2.7   |  3.3 |  3.8 |
# | |f(x)| 0.7419|  0.9933| 1.1939 | 1.3350  |
# |№26|x| 2.6 |3.0   |  3.0 |  4.5 |
# | |f(x)| 0.9555|  1,0986| 1,З610 | 1,5041  |
# |№27|x| 4.5 |4.9   |  5.5 |  6.0|
# | |f(x)| 1.5041|  1.5892| 1.7047 | 1.7916  |
# |№28|x| 3.5 |3.8   |  4.5 |  5.1 |
# | |f(x)| 1.2528|  1.3350| 1.5041 | 1.6292  |
# |№29|x| 2.6 |3.3   |  3.9 |  4.6 |
# | |f(x)| 1.0296|  1,1939| 1,З610 | 1,5261  |
# |№30|x| 4.1 |4.6   |  5.2 |  6.0 |
# | |f(x)| 1.4110|  1.5261| 1,6487 | 1,7918  |

# %% [markdown]
# [йцукен]: https://www.google.com.ua/search?ei=2pQ8W_y0DIGwUo6LpLAM&q=markdown+%D1%81%D1%81%D1%8B%D0%BB%D0%BA%D0%B8&oq=markdown+%D1%81%D1%81%D1%8B%D0%BB%D0%BA%D0%B8&gs_l=psy-ab.3...5956.8297.0.8825.10.10.0.0.0.0.351.964.0j3j1j1.5.0....0...1.1.64.psy-ab..5.5.962...0j35i39k1j0i67k1j0i20i263k1j0i22i30k1.0.mjKrVeQUpks

# %% [markdown]
# Check the result here:
